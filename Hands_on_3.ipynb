# %% [markdown]
# <a href="https://colab.research.google.com/github/AniruddhaYadav-AI/DAA/blob/main/Hands_on_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Runtime of the Algorithm (Mathematical Explanation)
# The function contains two nested loops, each running from 1 to
# 𝑛
# n. The total number of iterations is:
#
# T(n)=
# [(n
# ∑
# i=1)
#   (n
# ∑
# j=1) ]
#  1 = n × n = n ^
# 2
#
# So the time complexity is
# 𝑂(
# 𝑛 ^
# 2
# )

# %% [markdown]
# 2. Timing the Function and Polynomial Fitting

# %%
# Fitting a polynomial to the time data

# Fitting a 2nd degree polynomial since the theoretical complexity is O(n^2)
coeffs = np.polyfit(n_values, times, 2)
poly_fit = np.poly1d(coeffs)

# Generate the polynomial fit line for plotting
fit_times = poly_fit(n_values)

# Plotting the original times and the polynomial fit
plt.figure(figsize=(10, 6))
plt.plot(n_values, times, label="Original Times", color='blue')
plt.plot(n_values, fit_times, label=f"Polynomial Fit: {coeffs[0]:.2e}n^2 + {coeffs[1]:.2e}n + {coeffs[2]:.2e}", color='red')
plt.xlabel("n")
plt.ylabel("Time (seconds)")
plt.title("Time vs n with Polynomial Fit")
plt.legend()
plt.grid(True)
plt.show()

# Showing the polynomial expression
coeffs
# Out:
# array([ 2.06190740e-08,  3.32013358e-05, -2.46262405e-03])

# %% [markdown]
# The polynomial fit for the time data is:
#
# 𝑇 ( 𝑛 ) =
# 5.13
# ×
# (10^
# −
# 8)
# x
# (𝑛^
# 2)
# −
# 2.30
# ×
# (10^
# −
# 6𝑛)
# +
# 7.56
# ×
# (10^
# −
# 5)
#
# This quadratic fit aligns with the expected
# 𝑂
# (
# 𝑛^
# 2
# )
# complexity. The coefficient for
# 𝑛^
# 2
# is the dominant term, confirming that the algorithm's runtime grows quadratically as
# 𝑛
# increases.

# %% [markdown]
# 3. Big-O, Big-Omega, and Big-Theta
#
# Based on the polynomial fit and the mathematical analysis:
#
# Big-O (Upper Bound):
# 𝑂
# (
# 𝑛^
# 2
# )
#
#
# Big-Omega (Lower Bound):
# Ω
# (
# 𝑛^
# 2
# )
#
#
# Big-Theta (Tight Bound):
# Θ
# (
# 𝑛^
# 2
# )

# %% [markdown]
# 4. Finding Approximate Location of n_0

# %%
# Zooming in to find the approximate n_0 where deviation occurs
plt.figure(figsize=(10, 6))
plt.plot(n_values, times, label="Original Times", color='blue')
plt.plot(n_values, fit_times, label=f"Polynomial Fit", color='red')
plt.xlim(0, 100)  # Zoom into n values between 0 and 100
plt.xlabel("n")
plt.ylabel("Time (seconds)")
plt.title("Zoomed Time vs n (0 to 100)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Effect of Modifying the Function
#
# Will this increase how long the algorithm takes to run?
#
# Adding the line y = i + j introduces an additional constant-time operation in the innermost loop.  This change increases the constant factor very slightly. Therefore, it will slightly increase the runtime, but the overall complexity remains to be
# 𝑂
# (
# 𝑛^
# 2
# )
#
#
# Will it affect the results from #1?
#
# No, the overall time complexity will still be
# 𝑂
# (
# 𝑛^
# 2
# )
# , but the function will take slightly longer to run due to the extra operation.

# %% [markdown]
# 6. Implementing Merge Sort

# %%
# Merge sort implementation
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2  # Finding the mid of the array
        L = arr[:mid]  # Dividing the elements into 2 halves
        R = arr[mid:]

        merge_sort(L)  # Sorting the first half
        merge_sort(R)  # Sorting the second half

        i = j = k = 0

        # Copy data to temporary arrays L[] and R[]
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        # Checking if any element was left
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

# Test array
arr = [5, 2, 4, 7, 1, 3, 2, 6]
merge_sort(arr)
arr
# Out:
# [1, 2, 2, 3, 4, 5, 6, 7]
